# %% [markdown]
# https://www.nvidia.com/Download/index.aspx

# %% [markdown]
# https://developer.nvidia.com/cuda-downloads

# %%
# %pip install matplotlib==3.10.1 numpy==2.2.1 plotly==6.3.0 scipy==1.15.2 tqdm==4.67.1 torch==2.5.1+cu121 --index-url https://download.pytorch.org/whl/cu121

# %%
import matplotlib, numpy, plotly, scipy, torch, tqdm
print(matplotlib.__version__, numpy.__version__, plotly.__version__, scipy.__version__, torch.__version__, tqdm.__version__)

# %%
import platform
print(platform.platform())
print(platform.system(), platform.release(), platform.version())

# %%
import torch

print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))

# %%
import torch
import subprocess

print("PyTorch CUDA:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())

try:
    out = subprocess.check_output(["nvidia-smi"]).decode()
    print(out.split("\n")[2])
except:
    print("nvidia-smi not found")
